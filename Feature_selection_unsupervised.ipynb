# %% [markdown]
# <a href="https://colab.research.google.com/github/lakithav/ml-internship-journey/blob/main/Feature_selection_unsupervised.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.DataFrame({'Math':[70, 60, 40, 80, 30],
                    'Chemistry':[60, 80, 65, 55, 60],
                    'Maths':[70, 60, 40, 80, 30],
                    'Physics':[50, 50, 50, 50, 50],
                    'General_Test':[70, 70, 60, 60, 80]})
print(data)
# Out:
#    Math  Chemistry  Maths  Physics  General_Test
# 0    70         60     70       50            70
# 1    60         80     60       50            70
# 2    40         65     40       50            60
# 3    80         55     80       50            60
# 4    30         60     30       50            80

# %% [markdown]
# Variance

# %%
from sklearn.feature_selection import VarianceThreshold
selector = VarianceThreshold(threshold=0)
selected_features = selector.fit_transform(data)

# %%
data = pd.DataFrame(selected_features, columns=selector.get_feature_names_out())
print(data)
# Out:
#    Math  Chemistry  Maths  General_Test
# 0    70         60     70            70
# 1    60         80     60            70
# 2    40         65     40            60
# 3    80         55     80            60
# 4    30         60     30            80

# %% [markdown]
# Correlation

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cor = data.corr()
cor
# Out:
#                   Math  Chemistry     Maths  General_Test
# Math          1.000000  -0.150424  1.000000     -0.489932
# Chemistry    -0.150424   1.000000 -0.150424      0.124274
# Maths         1.000000  -0.150424  1.000000     -0.489932
# General_Test -0.489932   0.124274 -0.489932      1.000000

# %%
plt.figure(figsize=(10,10))
sns.heatmap(cor, annot=True, cmap="Wistia")
plt.show()

# %%
data = data.drop('Maths',axis=1)

# %%
data
# Out:
#    Math  Chemistry  General_Test
# 0    70         60            70
# 1    60         80            70
# 2    40         65            60
# 3    80         55            60
# 4    30         60            80
