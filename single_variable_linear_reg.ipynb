# %% [markdown]
# <a href="https://colab.research.google.com/github/lakithav/ml-internship-journey/blob/main/single_variable_linear_reg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
path = "/content/drive/MyDrive/DataSets/Book.csv"
data = pd.read_csv(path)
data
# Out:
#   Unnamed: 0  videos  views
# 0   channel1      30  34000
# 1   channel2      40  41000
# 2   channel3      50  42500
# 3   channel4      60  54300
# 4   channel5      70  56000

# %%
plt.scatter(data.videos,data.views,color = "red")
plt.xlabel("Num of videos")
plt.ylabel("Total views")
# Out:
# Text(0, 0.5, 'Total views')

# %%
data.views
# Out:
# 0    34000
# 1    41000
# 2    42500
# 3    54300
# 4    56000
# Name: views, dtype: int64

# %%
data.videos
# Out:
# 0    30
# 1    40
# 2    50
# 3    60
# 4    70
# Name: videos, dtype: int64

# %%
x= np.array(data.videos.values)
y= np.array(data.views.values)
x , y
# Out:
# (array([30, 40, 50, 60, 70]), array([34000, 41000, 42500, 54300, 56000]))

# %%
model = LinearRegression()
model.fit(x.reshape(-1,1),y)
# Out:
# LinearRegression()

# %%
new_x=np.array([45]).reshape((-1,1))
new_x
# Out:
# array([[45]])

# %%
pred=model.predict(new_x)
pred
# Out:
# array([42695.])

# %%
plt.scatter(data.videos,data.views,color = "red")
m,c = np.polyfit(x,y,1)
plt.plot(x,m*x+c)

# %%
m
# Out:
# np.float64(573.0)
