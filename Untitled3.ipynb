# %% [markdown]
# <a href="https://colab.research.google.com/github/lakithav/ml-internship-journey/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.DataFrame({
    'x':[0.2, 0.6, 0.3, 0.7],
    'y':[0.9, 0.3, 0.8, 0.2]
  })

# %%
data
# Out:
#      x    y
# 0  0.2  0.9
# 1  0.6  0.3
# 2  0.3  0.8
# 3  0.7  0.2

# %%
plt.scatter(data['x'],data['y'])

# %%
from sklearn.cluster import KMeans
model = KMeans(n_clusters=2)
model.fit(data)
label = model.predict(data)

# %%
label
# Out:
# array([1, 0, 1, 0], dtype=int32)

# %%
plt.scatter(data['x'],data['y'],c=label)

# %%
from sklearn.metrics import silhouette_score
sc=silhouette_score(data,label,metric='euclidean')
print(sc)
# Out:
# 0.8021339402214618
